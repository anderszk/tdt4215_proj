# %%
import gdown

gdown.download_folder('https://drive.google.com/drive/folders/1hXwBqSR64Oy0osTlBBPsnOeUIqaSEN-F')
gdown.download_folder('https://drive.google.com/drive/folders/1HDbp2OfpMNTJvP75OZpqr3B0sv3laQs6')
# Out:
# Retrieving folder contents
# Processing file 1SWUdi4dvhc8PLNcozUppxOehKQhxWiSI behaviors.tsv
# Processing file 1FKIxPmiWHOlk84UgrlhwxHQsYZW5uhD4 entity_embedding.vec
# Processing file 1EzuTtNF7jPW9c5soA8si9WqJslUaxLTq news.tsv
# Processing file 1wQXtAWsgJsKBkUwKxy4dQ9Lb18Nr5tAO relation_embedding.vec
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From: https://drive.google.com/uc?id=1SWUdi4dvhc8PLNcozUppxOehKQhxWiSI
# To: c:\Users\Hallvard\Music\recommender\tdt4215_proj\data\raw\Dataset-MIND-Validation-SET\behaviors.tsv
# 100%|██████████| 42.8M/42.8M [00:03<00:00, 11.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1FKIxPmiWHOlk84UgrlhwxHQsYZW5uhD4
# To: c:\Users\Hallvard\Music\recommender\tdt4215_proj\data\raw\Dataset-MIND-Validation-SET\entity_embedding.vec
# 100%|██████████| 22.0M/22.0M [00:02<00:00, 8.50MB/s]
# Downloading...
# ...
